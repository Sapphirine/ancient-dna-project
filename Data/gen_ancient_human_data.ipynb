# %%
import pandas as pd

df=pd.read_csv('./v62.0_1240k_public.anno',sep="\t")
anno= df[['Long.','Lat.','Skeletal element','Date mean in BP in years before 1950 CE [OxCal mu for a direct radiocarbon date, and average of range for a contextual date]','Age at death, Morphological sex from physical anthropology','Group ID','Locality','Political Entity']]
anno.head(5)
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_15916\3424091658.py:3: DtypeWarning: Columns (10,16,17) have mixed types. Specify dtype option on import or set low_memory=False.
#   df=pd.read_csv('./v62.0_1240k_public.anno',sep="\t")
#        Long.       Lat. Skeletal element  \
# 0        6.4      49.81            tooth
# 1   25.60652  36.937529               ..
# 2   25.60652  36.937529               ..
# 3  21.823641  39.980392               ..
# 4  21.823641  39.980392               ..
#
#    Date mean in BP in years before 1950 CE [OxCal mu for a direct radiocarbon date, and average of range for a contextual date]  \
# 0                                               8025
# 1                                               4250
# 2                                               4250
# 3                                               4250
# 4                                               4250
#
#   Age at death, Morphological sex from physical anthropology  \
# ...
